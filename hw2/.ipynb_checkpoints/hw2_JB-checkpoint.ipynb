# %%
import jieba
import jieba.analyse
import os
import sys
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
Food = ''
os.chdir("C:\\Users\\steven\\Desktop\\2018Summer\\python\\summer_python\\hw2\\Food")
for i in range(1,101):
    content = open('F_{0}.txt'.format(i),'r', encoding = 'utf8').read()
    Food = Food + content

words = jieba.cut(Food,cut_all=False)

tags = jieba.analyse.extract_tags(Food,60)
tags.sort()
print ('\n'.join(tags))

# %%
Mobile = ''
os.chdir("C:\\Users\\steven\\Desktop\\2018Summer\\python\\summer_python\\hw2\\Mobile")
for i in range(1,101):
    content = open('M_{0}.txt'.format(i),'r', encoding = 'utf8').read()
    Mobile = Mobile + content

words = jieba.cut(Mobile,cut_all=False)

tags = jieba.analyse.extract_tags(Mobile,60)
tags.sort()
print ('\n'.join(tags))
# Out:
# <class 'str'>

# %%
import jieba
import sys

from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
os.chdir("C:\\Users\\steven\\Desktop\\2018Summer\\python\\summer_python\\hw2\\Mobile")

corpus = []
f = open('M_1.txt', 'r',encoding='utf8')
for line in f:
    corpus.append(" ".join(jieba.cut(line.split(',')[0], cut_all=False)))
    
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(corpus)
print (tfidf.shape)

words = vectorizer.get_feature_names()


for j in range(len(corpus)):
    print (words[j].encode('utf-8'), tfidf[j])
# Out:
# (130, 407)
# ...

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
# vectorizer = CountVectorizer()

# corpus = ['我','是','好','人','你','是','好','人','嗎','我','愛','吃','薯','條','你','也','愛','吃','嗎']
# X = vectorizer.fit_transform(corpus)
# feature_name = vectorizer.get_feature_names()

# print (X)
# print (feature_name)
# print (X.toarray())

# # print(vectorizer.get_feature_names())

# %%
# transformer = TfidfTransformer()

# tfidf = transformer.fit_transform(X)

# print (tfidf.toarray())
